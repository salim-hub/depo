# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.arange(1,6)

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
y = np.arange(2,11,2)

# %%
y
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
plt.plot(x,y,"red")

# %%
plt.subplot(2,2,1)
plt.plot(x,y,"blue")
plt.subplot(2,2,2)
plt.plot(y,x,"yellow")
plt.subplot(2,2,3)
plt.plot(y,x,"red")
plt.subplot(2,2,4)
plt.plot(x,x**2,"black")
plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.arange(1,6)

y = np.arange(2,11,2)

fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.2,0.3])

axes1.plot(y,x)
axes1.set_xlabel("Outer X")
axes1.set_ylabel("Outer Y")
axes1.set_title("Outer Graph")

axes2.plot(x,y)
axes2.set_xlabel("Inner X")
axes2.set_ylabel("Inner Y")
axes2.set_title("Inner Graph")
plt.show()

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
y
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2)

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2)
plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1)
print(type(axes))
plt.tight_layout()
# Out:
# <class 'numpy.ndarray'>

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1)
print(axes)
plt.tight_layout()
# Out:
# [<AxesSubplot:> <AxesSubplot:>]

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1)
print(axes[0])
print(axes[1])
plt.tight_layout()
# Out:
# AxesSubplot(0.125,0.536818;0.775x0.343182)
# AxesSubplot(0.125,0.125;0.775x0.343182)

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1)

for ax in axes:
    ax.plot(x,y)

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1)

axes[0].plot(x,y)
axes[1].plot(x, x**3)

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1)

axes[0].plot(x,y)
axes[0].set_title("First Axes")
axes[1].plot(x, x**3)
axes[1].set_title("Second Axes")

plt.tight_layout()

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])
axes.plot(x,y,"purple")

# %%
fig = plt.figure(figsize = (3,3))

axes = fig.add_axes([0,0,1,1])
axes.plot(x,y,"purple")

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (8,6))

axes[0].plot(x,y,color="red")
axes[0].set_title("First Axes")
axes[1].plot(x,x**0.5, color="purple")
axes[1].set_title("Second Axes")
plt.tight_layout()

# %%
fig

# %%
fig.savefig("Figure1.png")

# %%
fig.savefig("Figure1.pdf")

# %%
fig = plt.figure(figsize=(5,4))

axes = fig.add_axes([0,0,1,1])

# %%
fig = plt.figure(figsize=(5,4))

axes = fig.add_axes([0,0,1,1])
axes.plot(x,x**0.5, color="red")
axes.plot(x,x**2, color="yellow")
axes.plot(x,x**3, color="#4055c2")

# %%
fig = plt.figure(figsize=(5,4))

axes = fig.add_axes([0,0,1,1])
axes.plot(x,x**0.5, color="red", label = "X Karekök")
axes.plot(x,x**2, color="yellow", label = "X Kare")
axes.plot(x,x**3, color="#4055c2", label = "X Küp")

axes.legend()

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])

axes.plot(x, x**2, color="red")

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])

axes.plot(x, x**2, color="red", linewidth=10)

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])

axes.plot(x, x**2, color="red", lw=3, linestyle="--")

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])

axes.plot(x, x**2, color="red", lw=3, linestyle=":")

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])

axes.plot(x, x**2, color="red", lw=3, linestyle="-.")

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])

axes.plot(x, x**2, color="red", lw=2, marker = "o")

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])

axes.plot(x, x**2, color="red", lw=2, marker = "o", markersize = 20, markerfacecolor = "black")

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])

axes.plot(x, x**2, color="red", lw=2, marker = "o", markersize = 20, markerfacecolor = "black", markeredgecolor ="yellow"
         ,markeredgewidth=5)

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])

axes.plot(x, x**2, color="red", lw=2, marker = "o", markersize = 10, markerfacecolor = "black", markeredgecolor ="yellow"
         ,markeredgewidth=3)

axes.set_xlim(0, 20)
# Out:
# (0.0, 20.0)

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])

axes.plot(x, x**2, color="red", lw=2, marker = "o", markersize = 10, markerfacecolor = "black", markeredgecolor ="yellow"
         ,markeredgewidth=3)

axes.set_xlim(0, 100)
# Out:
# (0.0, 100.0)

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])

axes.plot(x, x**2, color="red", lw=2, marker = "o", markersize = 10, markerfacecolor = "black", markeredgecolor ="yellow"
         ,markeredgewidth=3)

axes.set_xlim(0, 10)
# Out:
# (0.0, 10.0)

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])

axes.plot(x, x**2, color="red", lw=2, marker = "o", markersize = 10, markerfacecolor = "black", markeredgecolor ="yellow"
         ,markeredgewidth=3)

axes.set_xlim(0, 10)
axes.set_ylim(0, 50)
# Out:
# (0.0, 50.0)
